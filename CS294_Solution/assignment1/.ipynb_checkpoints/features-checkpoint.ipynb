# %% [markdown]
# # Image features exercise
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. For more details see the [assignment page](https://bcourses.berkeley.edu/courses/1453965/assignments/7738616) on the course website.*
#
# We have seen that we can achieve reasonable performance on an image classification task by training a linear classifier on the pixels of the input image. In this exercise we will show that we can improve our classification performance by training linear classifiers not on raw pixels but on features that are computed from the raw pixels.
#
# All of your work for this exercise will be done in this notebook.

# %%
import random
import numpy as np
from cs294_129.data_utils import load_CIFAR10
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Load data
# Similar to previous exercises, we will load CIFAR-10 data from disk.

# %%
from cs294_129.features import color_histogram_hsv, hog_feature

def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000):
  # Load the raw CIFAR-10 data
  cifar10_dir = 'cs294_129/datasets/cifar-10-batches-py'
  X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
  
  # Subsample the data
  mask = range(num_training, num_training + num_validation)
  X_val = X_train[mask]
  y_val = y_train[mask]
  mask = range(num_training)
  X_train = X_train[mask]
  y_train = y_train[mask]
  mask = range(num_test)
  X_test = X_test[mask]
  y_test = y_test[mask]

  return X_train, y_train, X_val, y_val, X_test, y_test

X_train, y_train, X_val, y_val, X_test, y_test = get_CIFAR10_data()

# %% [markdown]
# ## Extract Features
# For each image we will compute a Histogram of Oriented
# Gradients (HOG) as well as a color histogram using the hue channel in HSV
# color space. We form our final feature vector for each image by concatenating
# the HOG and color histogram feature vectors.
#
# Roughly speaking, HOG should capture the texture of the image while ignoring
# color information, and the color histogram represents the color of the input
# image while ignoring texture. As a result, we expect that using both together
# ought to work better than using either alone. Verifying this assumption would
# be a good thing to try for the bonus section.
#
# The `hog_feature` and `color_histogram_hsv` functions both operate on a single
# image and return a feature vector for that image. The extract_features
# function takes a set of images and a list of feature functions and evaluates
# each feature function on each image, storing the results in a matrix where
# each column is the concatenation of all feature vectors for a single image.

# %%
from cs294_129.features import *

num_color_bins = 10 # Number of bins in the color histogram
feature_fns = [hog_feature, lambda img: color_histogram_hsv(img, nbin=num_color_bins)]
X_train_feats = extract_features(X_train, feature_fns, verbose=True)
X_val_feats = extract_features(X_val, feature_fns)
X_test_feats = extract_features(X_test, feature_fns)

# Preprocessing: Subtract the mean feature
mean_feat = np.mean(X_train_feats, axis=0, keepdims=True)
X_train_feats -= mean_feat
X_val_feats -= mean_feat
X_test_feats -= mean_feat

# Preprocessing: Divide by standard deviation. This ensures that each feature
# has roughly the same scale.
std_feat = np.std(X_train_feats, axis=0, keepdims=True)
X_train_feats /= std_feat
X_val_feats /= std_feat
X_test_feats /= std_feat

# Preprocessing: Add a bias dimension
X_train_feats = np.hstack([X_train_feats, np.ones((X_train_feats.shape[0], 1))])
X_val_feats = np.hstack([X_val_feats, np.ones((X_val_feats.shape[0], 1))])
X_test_feats = np.hstack([X_test_feats, np.ones((X_test_feats.shape[0], 1))])
# Out:
# Done extracting features for 1000 / 49000 images
# Done extracting features for 2000 / 49000 images
# Done extracting features for 3000 / 49000 images
# Done extracting features for 4000 / 49000 images
# Done extracting features for 5000 / 49000 images
# Done extracting features for 6000 / 49000 images
# Done extracting features for 7000 / 49000 images
# Done extracting features for 8000 / 49000 images
# Done extracting features for 9000 / 49000 images
# Done extracting features for 10000 / 49000 images
# Done extracting features for 11000 / 49000 images
# Done extracting features for 12000 / 49000 images
# Done extracting features for 13000 / 49000 images
# Done extracting features for 14000 / 49000 images
# Done extracting features for 15000 / 49000 images
# Done extracting features for 16000 / 49000 images
# Done extracting features for 17000 / 49000 images
# Done extracting features for 18000 / 49000 images
# Done extracting features for 19000 / 49000 images
# ...

# %% [raw]
# ## Train SVM on features
# Using the multiclass SVM code developed earlier in the assignment, train SVMs on top of the features extracted above; this should achieve better results than training SVMs directly on top of raw pixels.

# %%
# Use the validation set to tune the learning rate and regularization strength

from cs294_129.classifiers.linear_classifier import LinearSVM

learning_rates = [1e-9, 1e-8, 1e-7]
regularization_strengths = [1e5, 1e6, 1e7]

results = {}
best_val = -1
best_svm = None


################################################################################
# TODO:                                                                        #
# Use the validation set to set the learning rate and regularization strength. #
# This should be identical to the validation that you did for the SVM; save    #
# the best trained classifer in best_svm. You might also want to play          #
# with different numbers of bins in the color histogram. If you are careful    #
# you should be able to get accuracy of near 0.44 on the validation set.       #
################################################################################
iters = 1500
for lr in learning_rates:
    for rs in regularization_strengths:
        svm = LinearSVM()
        svm.train(X_train_feats, y_train, learning_rate=lr, reg=rs, num_iters=iters)
        
        y_train_pred = svm.predict(X_train_feats)
        #accuracy_train = np.mean(y_train == y_train_pred)
        #print(y_train.shape)
        #print(y_train_pred.shape)
        accuracy_train = np.mean(np.equal(y_train, y_train_pred))
        y_val_pred = svm.predict(X_val_feats)
        accuracy_validation = np.mean(np.equal(y_val, y_val_pred))
        
        results[(lr, rs)]=(accuracy_train, accuracy_validation)
        
        if best_val < accuracy_validation:
            best_val = accuracy_validation
            best_svm = svm
################################################################################
#                              END OF YOUR CODE                                #
################################################################################

# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print 'lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy)
    
print 'best validation accuracy achieved during cross-validation: %f' % best_val
# Out:
# lr 1.000000e-09 reg 1.000000e+05 train accuracy: 0.090878 val accuracy: 0.088000
# lr 1.000000e-09 reg 1.000000e+06 train accuracy: 0.107694 val accuracy: 0.095000
# lr 1.000000e-09 reg 1.000000e+07 train accuracy: 0.414306 val accuracy: 0.416000
# lr 1.000000e-08 reg 1.000000e+05 train accuracy: 0.109633 val accuracy: 0.111000
# lr 1.000000e-08 reg 1.000000e+06 train accuracy: 0.416469 val accuracy: 0.423000
# lr 1.000000e-08 reg 1.000000e+07 train accuracy: 0.405653 val accuracy: 0.393000
# lr 1.000000e-07 reg 1.000000e+05 train accuracy: 0.414286 val accuracy: 0.414000
# lr 1.000000e-07 reg 1.000000e+06 train accuracy: 0.404571 val accuracy: 0.385000
# lr 1.000000e-07 reg 1.000000e+07 train accuracy: 0.330143 val accuracy: 0.333000
# best validation accuracy achieved during cross-validation: 0.423000

# %%
# Evaluate your trained SVM on the test set
y_test_pred = best_svm.predict(X_test_feats)
test_accuracy = np.mean(y_test == y_test_pred)
print test_accuracy
# Out:
# 0.423

# %%
# An important way to gain intuition about how an algorithm works is to
# visualize the mistakes that it makes. In this visualization, we show examples
# of images that are misclassified by our current system. The first column
# shows images that our system labeled as "plane" but whose true label is
# something other than "plane".

examples_per_class = 8
classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for cls, cls_name in enumerate(classes):
    idxs = np.where((y_test != cls) & (y_test_pred == cls))[0]
    idxs = np.random.choice(idxs, examples_per_class, replace=False)
    for i, idx in enumerate(idxs):
        plt.subplot(examples_per_class, len(classes), i * len(classes) + cls + 1)
        plt.imshow(X_test[idx].astype('uint8'))
        plt.axis('off')
        if i == 0:
            plt.title(cls_name)
plt.show()

# %% [markdown]
# ### Inline question 1:
# Describe the misclassification results that you see. Do they make sense?

# %% [markdown]
# In this problem, we are using HOG and color histograms as features. The mistakes seem bad but is reasonable as the features tend to clasfiy images with similar background as the same class (color histogram) and images with similar edges as the same class (HOG).

# %% [markdown]
# ## Neural Network on image features
# Earlier in this assigment we saw that training a two-layer neural network on raw pixels achieved better classification performance than linear classifiers on raw pixels. In this notebook we have seen that linear classifiers on image features outperform linear classifiers on raw pixels.
#
# For completeness, we should also try training a neural network on image features. This approach should outperform all previous approaches: you should easily be able to achieve over 55% classification accuracy on the test set; our best model achieves about 60% classification accuracy.

# %%
print X_train_feats.shape
# Out:
# (49000, 155)

# %%
from cs294_129.classifiers.neural_net import TwoLayerNet 


input_dim = X_train_feats.shape[1]
hidden_dim = 650
num_classes = 10

net = TwoLayerNet(input_dim, hidden_dim, num_classes)
best_net = None

################################################################################
# TODO: Train a two-layer neural network on image features. You may want to    #
# cross-validate various parameters as in previous sections. Store your best   #
# model in the best_net variable.                                              #
################################################################################
best_val = -1
best_history = None
learning_rates = np.logspace(-10, 0, 10)
# regularization_strengths = [1e5, 1e6, 1e7]
regularization_strengths = np.logspace(-3, 15, 15)

results = {}
iters = 1000
for i in learning_rates:
    for j in regularization_strengths:
        net = TwoLayerNet(input_dim, hidden_dim, num_classes)
        
        history = net.train(X_train_feats, y_train, X_val_feats, y_val,
                           num_iters=iters, batch_size = 200, learning_rate = i, 
                           learning_rate_decay = 0.95, reg = j)
        y_train_pred = net.predict(X_train_feats)
        accuracy_train = np.mean(np.equal(y_train, y_train_pred))
        y_val_pred = net.predict(X_val_feats)
        accuracy_val = np.mean(np.equal(y_val, y_val_pred))
        
        results[(i, j)] = (accuracy_train, accuracy_val)
        
        if best_val < accuracy_val:
            best_history = history 
            best_val = accuracy_val
            best_net = net


for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print 'lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy)
    
print 'best validation accuracy achieved during cross-validation: %f' % best_val

################################################################################
#                              END OF YOUR CODE                                #
################################################################################
# Out:
# lr 1.000000e-10 reg 1.000000e-03 train accuracy: 0.099816 val accuracy: 0.098000
# lr 1.000000e-10 reg 1.930698e-02 train accuracy: 0.105633 val accuracy: 0.083000
# lr 1.000000e-10 reg 3.727594e-01 train accuracy: 0.116102 val accuracy: 0.110000
# lr 1.000000e-10 reg 7.196857e+00 train accuracy: 0.093082 val accuracy: 0.091000
# lr 1.000000e-10 reg 1.389495e+02 train accuracy: 0.103755 val accuracy: 0.113000
# lr 1.000000e-10 reg 2.682696e+03 train accuracy: 0.109571 val accuracy: 0.112000
# lr 1.000000e-10 reg 5.179475e+04 train accuracy: 0.104469 val accuracy: 0.101000
# lr 1.000000e-10 reg 1.000000e+06 train accuracy: 0.117163 val accuracy: 0.120000
# lr 1.000000e-10 reg 1.930698e+07 train accuracy: 0.113449 val accuracy: 0.117000
# lr 1.000000e-10 reg 3.727594e+08 train accuracy: 0.100429 val accuracy: 0.079000
# lr 1.000000e-10 reg 7.196857e+09 train accuracy: 0.100449 val accuracy: 0.078000
# lr 1.000000e-10 reg 1.389495e+11 train accuracy: 0.100265 val accuracy: 0.087000
# ...

# %% [markdown]
#  The Best Validation was 57.0%.

# %%
# Run your neural net classifier on the test set. You should be able to
# get more than 55% accuracy.

test_acc = (best_net.predict(X_test_feats) == y_test).mean()
print test_acc
# Out:
# 0.566

# %% [markdown]
# The best test accuracy was 56.6%

# %% [markdown]
# # Bonus: Design your own features!
#
# You have seen that simple image features can improve classification performance. So far we have tried HOG and color histograms, but other types of features may be able to achieve even better classification performance.
#
# For bonus points, design and implement a new type of feature and use it for image classification on CIFAR-10. Explain how your feature works and why you expect it to be useful for image classification. Implement it in this notebook, cross-validate any hyperparameters, and compare its performance to the HOG + Color histogram baseline.

# %% [markdown]
# # Bonus: Do something extra!
# Use the material and code we have presented in this assignment to do something interesting. Was there another question we should have asked? Did any cool ideas pop into your head as you were working on the assignment? This is your chance to show off!

# %% [markdown]
# We will verify that simply using either HOG or the Color histogram will not outperform the model using both HOG + Color Histogram. We do so by only usng the hog features (First 144 columns) and the color histogram features (Next 10 Features) separately.

# %%
X_val_feats.shape
# Out:
# (1000, 155)

# %%
y_val.shape
# Out:
# (1000,)

# %% [markdown]
# ## Hog - Only Model

# %%
(X_train_feats[:, 0:144]).shape
# Out:
# (49000, 144)

# %%
from cs294_129.classifiers.neural_net import TwoLayerNet

X_hog_train_feats = np.hstack([X_train_feats[:, 0:144] , np.ones((X_train_feats.shape[0], 1))])
print(X_hog_train_feats.shape)
X_hog_val_feats = np.hstack([X_val_feats[:, 0:144], np.ones((X_val_feats.shape[0], 1))])
print(X_hog_val_feats.shape)
X_hog_test_feats = np.hstack([X_test_feats[:, 0:144], np.ones((X_test_feats.shape[0], 1))])
print(X_hog_test_feats.shape)


input_dim = X_hog_train_feats.shape[1]
print(X_hog_train_feats.shape)
hidden_dim = 650
num_classes = 10

net = TwoLayerNet(input_dim, hidden_dim, num_classes)
best_net = None

################################################################################
# TODO: Train a two-layer neural network on image features. You may want to    #
# cross-validate various parameters as in previous sections. Store your best   #
# model in the best_net variable.                                              #
################################################################################
best_val = -1
best_history = None
learning_rates = np.logspace(-10, 0, 10)
# regularization_strengths = [1e5, 1e6, 1e7]
regularization_strengths = np.logspace(-3, 15, 15)

results = {}
iters = 1000
for i in learning_rates:
    for j in regularization_strengths:
        net = TwoLayerNet(input_dim, hidden_dim, num_classes)
        
        history = net.train(X_hog_train_feats, y_train, X_hog_val_feats, y_val,
                           num_iters=iters, batch_size = 200, learning_rate = i, 
                           learning_rate_decay = 0.95, reg = j)
        y_train_pred = net.predict(X_hog_train_feats)
        accuracy_train = np.mean(np.equal(y_train, y_train_pred))
        y_val_pred = net.predict(X_hog_val_feats)
        accuracy_val = np.mean(np.equal(y_val, y_val_pred))
        
        results[(i, j)] = (accuracy_train, accuracy_val)
        
        if best_val < accuracy_val:
            best_history = history 
            best_val = accuracy_val
            best_net = net


for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print 'lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy)
    
print 'best validation accuracy achieved during cross-validation: %f' % best_val

################################################################################
#                              END OF YOUR CODE                                #
################################################################################
# Out:
# (49000, 145)
# (1000, 145)
# (1000, 145)
# (49000, 145)
# lr 1.000000e-10 reg 1.000000e-03 train accuracy: 0.109449 val accuracy: 0.102000
# lr 1.000000e-10 reg 1.930698e-02 train accuracy: 0.103184 val accuracy: 0.087000
# lr 1.000000e-10 reg 3.727594e-01 train accuracy: 0.088653 val accuracy: 0.084000
# lr 1.000000e-10 reg 7.196857e+00 train accuracy: 0.092061 val accuracy: 0.098000
# lr 1.000000e-10 reg 1.389495e+02 train accuracy: 0.103714 val accuracy: 0.096000
# lr 1.000000e-10 reg 2.682696e+03 train accuracy: 0.083633 val accuracy: 0.070000
# lr 1.000000e-10 reg 5.179475e+04 train accuracy: 0.103673 val accuracy: 0.100000
# lr 1.000000e-10 reg 1.000000e+06 train accuracy: 0.091816 val accuracy: 0.099000
# lr 1.000000e-10 reg 1.930698e+07 train accuracy: 0.093531 val accuracy: 0.096000
# lr 1.000000e-10 reg 3.727594e+08 train accuracy: 0.100041 val accuracy: 0.098000
# lr 1.000000e-10 reg 7.196857e+09 train accuracy: 0.100429 val accuracy: 0.079000
# ...

# %%
# Run your neural net classifier on the test set. You should be able to
# get more than 55% accuracy.

test_acc = (best_net.predict(X_hog_test_feats) == y_test).mean()
print test_acc
# Out:
# 0.552

# %% [markdown]
# As we can see the Hog-only model had the best validation accuracy of 54.2% (lower than 57% achieved when both were used) and had a lower test accuracy of 55.2%.

# %% [markdown]
# # Color Histogram Only

# %%
from cs294_129.classifiers.neural_net import TwoLayerNet

X_ch_train_feats = X_train_feats[:, 144:] 
print(X_ch_train_feats.shape)
X_ch_val_feats = X_val_feats[:, 144:]
print(X_ch_val_feats.shape)
X_ch_test_feats = X_test_feats[:, 144:]
print(X_ch_val_feats.shape)



input_dim = X_ch_train_feats.shape[1]
print(input_dim)
hidden_dim = 650
num_classes = 10

net = TwoLayerNet(input_dim, hidden_dim, num_classes)
best_net = None

################################################################################
# TODO: Train a two-layer neural network on image features. You may want to    #
# cross-validate various parameters as in previous sections. Store your best   #
# model in the best_net variable.                                              #
################################################################################
best_val = -1
best_history = None
learning_rates = np.logspace(-10, 0, 10)
# regularization_strengths = [1e5, 1e6, 1e7]
regularization_strengths = np.logspace(-3, 15, 15)

results = {}
iters = 1000
for i in learning_rates:
    for j in regularization_strengths:
        net = TwoLayerNet(input_dim, hidden_dim, num_classes)
        
        history = net.train(X_ch_train_feats, y_train, X_ch_val_feats, y_val,
                           num_iters=iters, batch_size = 200, learning_rate = i, 
                           learning_rate_decay = 0.95, reg = j)
        y_train_pred = net.predict(X_ch_train_feats)
        accuracy_train = np.mean(np.equal(y_train, y_train_pred))
        y_val_pred = net.predict(X_ch_val_feats)
        accuracy_val = np.mean(np.equal(y_val, y_val_pred))
        
        results[(i, j)] = (accuracy_train, accuracy_val)
        
        if best_val < accuracy_val:
            best_history = history 
            best_val = accuracy_val
            best_net = net


for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print 'lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy)
    
print 'best validation accuracy achieved during cross-validation: %f' % best_val

################################################################################
#                              END OF YOUR CODE                                #
################################################################################
# Out:
# (49000, 11)
# (1000, 11)
# (1000, 11)
# 11
# lr 1.000000e-10 reg 1.000000e-03 train accuracy: 0.052571 val accuracy: 0.054000
# lr 1.000000e-10 reg 1.930698e-02 train accuracy: 0.091694 val accuracy: 0.114000
# lr 1.000000e-10 reg 3.727594e-01 train accuracy: 0.073429 val accuracy: 0.064000
# lr 1.000000e-10 reg 7.196857e+00 train accuracy: 0.084980 val accuracy: 0.081000
# lr 1.000000e-10 reg 1.389495e+02 train accuracy: 0.106286 val accuracy: 0.117000
# lr 1.000000e-10 reg 2.682696e+03 train accuracy: 0.098837 val accuracy: 0.110000
# lr 1.000000e-10 reg 5.179475e+04 train accuracy: 0.106367 val accuracy: 0.116000
# lr 1.000000e-10 reg 1.000000e+06 train accuracy: 0.115000 val accuracy: 0.127000
# lr 1.000000e-10 reg 1.930698e+07 train accuracy: 0.096000 val accuracy: 0.108000
# lr 1.000000e-10 reg 3.727594e+08 train accuracy: 0.099735 val accuracy: 0.113000
# lr 1.000000e-10 reg 7.196857e+09 train accuracy: 0.100265 val accuracy: 0.087000
# ...

# %%
# Run your neural net classifier on the test set. You should be able to
# get more than 55% accuracy.

test_acc = (best_net.predict(X_ch_test_feats) == y_test).mean()
print test_acc
# Out:
# 0.243

# %% [markdown]
# As we can see the color histogram - only model had the best validation accuracy of 28.4% (lower than 57% achieved when both were used) and had a much lower test accuracy of 24.3%.
